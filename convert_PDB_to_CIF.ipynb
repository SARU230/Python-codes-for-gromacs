# %% [markdown]
# <a href="https://colab.research.google.com/github/SARU230/Python-codes-for-gromacs/blob/main/convert_PDB_to_CIF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab

import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !mamba install -c conda-forge rdkit
# Out:
# Looking for: ['rdkit']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - rdkit
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                         Version  Build                Channel           Size
# ────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────────────
#
#   + libgcc                         14.2.0  h77fa898_1           conda-forge      849kB
#   + libexpat                        2.6.4  h5888daf_0           conda-forge       73kB
#   + xorg-xorgproto                 2024.1  hb9d3cd8_1           conda-forge      565kB
# ...

# %%
pip install ase

# %%
import os
from rdkit import Chem
from ase import io

def convert_pdb_to_cif(pdb_file):

    try:
        structure = io.read(pdb_file)
        cif_file = os.path.splitext(pdb_file)[0] + '.cif'
        structure.write(cif_file)
        print(f"Converted {pdb_file} to {cif_file}")
    except Exception as e:
        print(f"Error converting {pdb_file}: {e}")

def process_files_in_directory():
    directory = os.getcwd()
    for filename in os.listdir(directory):
        if filename.startswith("Tips_") and filename.endswith(".pdb"):
            pdb_path = os.path.join(directory, filename)
            convert_pdb_to_cif(pdb_path)
#destination="F:/OneDrive - University of Kentucky/UK work/Research/Karl/TIPS_PN/Tips_Pen_293K_PDB"
process_files_in_directory()
# Out:
# Converted /content/Tips_Pen_293K0.pdb to /content/Tips_Pen_293K0.cif
